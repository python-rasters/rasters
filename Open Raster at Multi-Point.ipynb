# %%
import rasters as rt

# %%
filename = "GEDI_11SLT.tif"
image = rt.Raster.open(filename)
image

# %%
geometry = rt.MultiPoint([(-118, 34), (-119, 35)])
geometry
# Out:
# MULTIPOINT ((-118 34), (-119 35))

# %%
for point in geometry:
    print(point)
# Out:
# POINT (-118 34)
# POINT (-119 35)

# %%
# geometry = rt.Point(-118.589, 34.088)
# geometry

# %%
geometry.x
# Out:
# array([-118., -119.])

# %%
geometry.y
# Out:
# array([34., 35.])

# %%
geometry.bbox
# Out:
# BBox(xmin=-119.0, ymin=34.0, xmax=-118.0, ymax=35.0, crs="EPSG:4326")

# %%
image.geometry.window(geometry, buffer=1)
# Out:
# Window(col_off=508, row_off=0, width=3118, height=1249)

# %%
rt.Raster.open(filename, geometry=geometry)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsError                          Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 rt.Raster.open(filename, geometry=geometry)
#
# File ~/Projects/rasters/rasters/raster.py:424, in Raster.open(cls, filename, nodata, remove, geometry, buffer, window, resampling, cmap, **kwargs)
#     421 values = []
#     423 for point in geometry:
# --> 424     value = cls.open(
#     425         filename=filename,
#     426         nodata=nodata,
#     427         remove=remove,
#     428         geometry=point,
#     429         buffer=buffer,
#     430         window=window,
#     431         resampling=resampling,
#     432         cmap=cmap,
#     433         **kwargs
#     434     )
#     436     if isinstance(value, Raster):
#     437         value = value.to_point(point)
#
# File ~/Projects/rasters/rasters/raster.py:459, in Raster.open(cls, filename, nodata, remove, geometry, buffer, window, resampling, cmap, **kwargs)
#     456     buffer = 1
#     458 if window is None and target_geometry is not None:
# --> 459     window = source_geometry.window(geometry=target_geometry, buffer=buffer)
#     461 if window is not None and not isinstance(window, Window):
#     462     raise ValueError("invalid window")
#
# File ~/Projects/rasters/rasters/raster_grid.py:508, in RasterGrid.window(self, geometry, buffer)
#     505 rows, cols = self.shape
#     507 if row_end < 0 or col_end < 0 or row_start > rows or col_start > cols:
# --> 508     raise OutOfBoundsError("target geometry is not within source geometry")
#     510 if buffer is not None:
#     511     row_start -= buffer
#
# OutOfBoundsError: target geometry is not within source geometry
