# %%
import rasters as rt

# %%
filename = "GEDI_11SLT.tif"
image = rt.Raster.open(filename)
image

# %%
geometry = rt.Point(-118.589, 34.088)
geometry
# Out:
# POINT (-118.589 34.088)

# %%
geometry.bbox
# Out:
# BBox(xmin=-118.589, ymin=34.088, xmax=-118.589, ymax=34.088, crs="EPSG:4326")

# %%
image.geometry.window(geometry, buffer=1)
# Out:
# Window(col_off=1779, row_off=898, width=3, height=3)

# %%
rt.Raster.open(filename, geometry=geometry)
# Out:
# 13.80802350043292
